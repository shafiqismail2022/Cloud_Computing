# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris=pd.read_csv('Iris_data.csv')

# %%
sns.heatmap(iris.isnull(),cmap='plasma',cbar=False,yticklabels=False)
# Out:
# <Axes: >
